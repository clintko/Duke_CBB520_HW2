# %%
source config.sh

# %%
ls $RAW_FASTQS
# Out:
# SRR4841864_1.fastq  SRR4841864_2.fastq  SRR4841864.sra

# %%
ls $GENOME
# Out:
# Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.amb
# Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.ann
# Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.bwt
# Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.gz
# Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.pac
# Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.sa

# %%
echo $GENOME/$FA.gz
# Out:
# /home/jovyan/work/Data/SRR4841864/genome/Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa.gz

# %%
echo $ALIGN_RAW
# Out:
# /home/jovyan/work/Data/SRR4841864/align_raw

# %% [markdown]
# https://github.com/lh3/bwa
# ```
# git clone https://github.com/lh3/bwa.git
# cd bwa; make
# ./bwa index ref.fa
# ./bwa mem ref.fa read-se.fq.gz | gzip -3 > aln-se.sam.gz
# ./bwa mem ref.fa read1.fq read2.fq | gzip -3 > aln-pe.sam.gz
# ```

# %%
lscpu
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              12
# On-line CPU(s) list: 0-11
# Thread(s) per core:  2
# Core(s) per socket:  6
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               158
# Model name:          Intel(R) Core(TM) i7-8700K CPU @ 3.70GHz
# Stepping:            10
# CPU MHz:             1533.946
# CPU max MHz:         4700.0000
# CPU min MHz:         800.0000
# BogoMIPS:            7392.00
# Virtualization:      VT-x
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            12288K
# NUMA node0 CPU(s):   0-11
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush dts acpi mmx fxsr sse sse2 ss ht tm pbe syscall nx pdpe1gb rdtscp lm constant_tsc art arch_perfmon pebs bts rep_good nopl xtopology nonstop_tsc cpuid aperfmperf tsc_known_freq pni pclmulqdq dtes64 monitor ds_cpl vmx smx est tm2 ssse3 sdbg fma cx16 xtpr pdcm pcid sse4_1 sse4_2 x2apic movbe popcnt tsc_deadline_timer aes xsave avx f16c rdrand lahf_lm abm 3dnowprefetch cpuid_fault invpcid_single pti ssbd ibrs ibpb stibp tpr_shadow vnmi flexpriority ept vpid ept_ad fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx rdseed adx smap clflushopt intel_pt xsaveopt xsavec xgetbv1 xsaves dtherm ida arat pln pts hwp hwp_notify hwp_act_window hwp_epp md_clear flush_l1d

# %%
-M -t 16
-t INT	Number of threads [1]
-M	Mark shorter split hits as secondary (for Picard compatibility).

# %%
REFFA=$GENOME/$FA
READ1=$RAW_FASTQS/SRR4841864_1.fastq
READ2=$RAW_FASTQS/SRR4841864_2.fastq
bwa mem -t 8 $REFFA $READ1 $READ2 > $ALIGN_RAW/aln_pe.sam
# Out:
# [M::bwa_idx_load_from_disk] read 0 ALT contigs
# [M::process] read 792080 sequences (80000080 bp)...
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (2, 341412, 24, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (223, 290, 352)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 610)
# [M::mem_pestat] mean and std.dev: (289.36, 95.27)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 739)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (134, 263, 1100)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3032)
# [M::mem_pestat] mean and std.dev: (549.25, 596.06)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3998)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.465 CPU sec, 4.914 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (1, 341633, 25, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (221, 289, 351)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 611)
# [M::mem_pestat] mean and std.dev: (287.65, 95.26)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 741)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (122, 927, 1123)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3125)
# [M::mem_pestat] mean and std.dev: (659.33, 539.59)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 4126)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 41.222 CPU sec, 5.077 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (2, 341512, 26, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (218, 286, 348)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 608)
# [M::mem_pestat] mean and std.dev: (284.82, 94.57)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 738)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (134, 245, 569)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 1439)
# [M::mem_pestat] mean and std.dev: (361.25, 351.41)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1874)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 42.117 CPU sec, 5.186 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 341280, 23, 1)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (220, 288, 350)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 610)
# [M::mem_pestat] mean and std.dev: (286.85, 95.15)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 740)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (243, 976, 1241)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3237)
# [M::mem_pestat] mean and std.dev: (894.91, 749.77)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 4235)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 40.897 CPU sec, 5.054 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 341181, 26, 1)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (221, 289, 351)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 611)
# [M::mem_pestat] mean and std.dev: (287.98, 95.59)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 741)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (120, 290, 902)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2466)
# [M::mem_pestat] mean and std.dev: (467.58, 404.92)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3248)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 40.623 CPU sec, 5.004 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (3, 341540, 19, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (219, 287, 350)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 612)
# [M::mem_pestat] mean and std.dev: (286.27, 95.23)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 743)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (150, 194, 347)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 741)
# [M::mem_pestat] mean and std.dev: (163.93, 82.05)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 938)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 40.774 CPU sec, 5.035 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (4, 341720, 25, 1)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (219, 288, 350)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 612)
# [M::mem_pestat] mean and std.dev: (286.46, 95.16)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 743)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (85, 285, 999)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2827)
# [M::mem_pestat] mean and std.dev: (430.96, 464.86)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3741)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 40.828 CPU sec, 5.016 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (2, 343013, 20, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (228, 295, 358)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 618)
# [M::mem_pestat] mean and std.dev: (294.40, 96.52)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 748)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (118, 256, 1095)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3049)
# [M::mem_pestat] mean and std.dev: (670.85, 683.36)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 4026)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.631 CPU sec, 4.867 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 343350, 32, 3)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (227, 295, 357)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 617)
# [M::mem_pestat] mean and std.dev: (293.72, 96.42)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 747)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (139, 319, 1155)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3187)
# [M::mem_pestat] mean and std.dev: (572.83, 524.62)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 4203)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.483 CPU sec, 4.850 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (5, 343309, 28, 1)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (225, 293, 355)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 615)
# [M::mem_pestat] mean and std.dev: (291.98, 96.34)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 745)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (77, 162, 1219)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3503)
# [M::mem_pestat] mean and std.dev: (506.38, 561.45)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 4645)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.265 CPU sec, 4.803 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 342442, 27, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (226, 294, 357)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 619)
# [M::mem_pestat] mean and std.dev: (293.43, 96.92)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 750)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (194, 307, 1104)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2924)
# [M::mem_pestat] mean and std.dev: (617.59, 523.50)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3834)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.265 CPU sec, 4.849 real sec
# [M::process] read 792080 sequences (80000080 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (6, 342323, 19, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (226, 294, 357)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 619)
# [M::mem_pestat] mean and std.dev: (293.48, 96.86)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 750)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (139, 254, 371)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 835)
# [M::mem_pestat] mean and std.dev: (195.87, 117.43)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 1067)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.321 CPU sec, 4.833 real sec
# [M::process] read 486404 sequences (49126804 bp)...
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (0, 342617, 26, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (225, 293, 356)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 618)
# [M::mem_pestat] mean and std.dev: (292.37, 96.68)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 749)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (120, 260, 1155)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 3225)
# [M::mem_pestat] mean and std.dev: (676.81, 688.85)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 4260)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 792080 reads in 39.286 CPU sec, 4.845 real sec
# [M::mem_pestat] # candidate unique pairs for (FF, FR, RF, RR): (1, 210269, 18, 0)
# [M::mem_pestat] skip orientation FF as there are not enough pairs
# [M::mem_pestat] analyzing insert size distribution for orientation FR...
# [M::mem_pestat] (25, 50, 75) percentile: (223, 291, 354)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 616)
# [M::mem_pestat] mean and std.dev: (290.35, 96.64)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 747)
# [M::mem_pestat] analyzing insert size distribution for orientation RF...
# [M::mem_pestat] (25, 50, 75) percentile: (83, 170, 997)
# [M::mem_pestat] low and high boundaries for computing mean and std.dev: (1, 2825)
# [M::mem_pestat] mean and std.dev: (402.17, 433.61)
# [M::mem_pestat] low and high boundaries for proper pairs: (1, 3739)
# [M::mem_pestat] skip orientation RR as there are not enough pairs
# [M::mem_pestat] skip orientation RF
# [M::mem_process_seqs] Processed 486404 reads in 24.396 CPU sec, 3.012 real sec
# [main] Version: 0.7.17-r1198-dirty
# [main] CMD: bwa mem -t 8 /home/jovyan/work/Data/SRR4841864/genome/Saccharomyces_cerevisiae.R64-1-1.dna.toplevel.fa /home/jovyan/work/Data/SRR4841864/rawdata/SRR4841864_1.fastq /home/jovyan/work/Data/SRR4841864/rawdata/SRR4841864_2.fastq
# [main] Real time: 68.845 sec; CPU: 547.535 sec
